# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
df = pd.read_csv('student_marks.csv')
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
df.study_hours.mean()
# Out:
# 6.9959487179487185

# %%
df =df.fillna(df.study_hours.mean())
df
# Out:
#      study_hours  student_marks
# 0       6.830000          78.50
# 1       6.560000          76.74
# 2       6.995949          78.68
# 3       5.670000          71.82
# 4       8.670000          84.19
# ..           ...            ...
# 195     7.530000          81.67
# 196     8.560000          84.68
# 197     8.940000          86.75
# 198     6.600000          78.05
# 199     8.350000          83.50
#
# [200 rows x 2 columns]

# %%
X = df.drop(columns=['student_marks', 'predicted_y', 'absolute_loss'])
X
# Out:
#      study_hours
# 0       6.830000
# 1       6.560000
# 2       6.995949
# 3       5.670000
# 4       8.670000
# ..           ...
# 195     7.530000
# 196     8.560000
# 197     8.940000
# 198     6.600000
# 199     8.350000
#
# [200 rows x 1 columns]

# %%
y= df[['student_marks']]
y
# Out:
#      student_marks
# 0            78.50
# 1            76.74
# 2            78.68
# 3            71.82
# 4            84.19
# ..             ...
# 195          81.67
# 196          84.68
# 197          86.75
# 198          78.05
# 199          83.50
#
# [200 rows x 1 columns]

# %%
mean_x = X.mean()
mean_y = y.mean()
mean_x,mean_y
# Out:
# (study_hours    6.995949
#  dtype: float64,
#  77.93375)

# %%
plt.scatter(df.study_hours, df.student_marks)
plt.xlabel("Students Study Hours")
plt.ylabel("Students marks")
plt.title("Scatter Plot of Students Study Hours vs Students marks")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Students Study Hours vs Students marks')

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size =0.2)

# %%
X_train,y_train
# Out:
# (     study_hours
#  114         7.12
#  62          6.35
#  78          5.09
#  105         6.46
#  145         8.95
#  ..           ...
#  137         5.14
#  195         7.53
#  123         7.62
#  50          5.09
#  144         8.11
#
#  [160 rows x 1 columns],
#       student_marks
#  114          78.42
#  62           76.19
#  78           70.05
#  105          77.07
#  145          85.15
#  ..             ...
#  137          71.22
#  195          81.67
#  123          79.53
#  50           72.22
#  144          83.82
#
#  [160 rows x 1 columns])

# %%
X_test
# Out:
#      study_hours
# 131         5.26
# 162         7.79
# 119         6.60
# 46          7.01
# 197         8.94
# 45          6.18
# 180         6.97
# 198         6.60
# 84          6.88
# 40          5.28
# 116         5.40
# 65          5.45
# 146         7.99
# 115         5.79
# 95          6.09
# 37          7.19
# 4           8.67
# 97          5.20
# 178         8.42
# 70          5.37
# 104         7.23
# 99          8.07
# 100         6.24
# 39          7.88
# 42          5.46
# 3           5.67
# 193         7.55
# 106         5.34
# 9           6.75
# 29          7.48
# 7           8.99
# 10          6.59
# 192         8.71
# 194         6.35
# 47          5.01
# 19          7.67
# 157         6.18
# 1           6.56
# 61          7.26
# 152         8.08

# %%
y_test
# Out:
#      student_marks
# 131          71.86
# 162          79.17
# 119          75.55
# 46           77.46
# 197          86.75
# 45           72.96
# 180          77.19
# 198          78.05
# 84           77.29
# 40           70.27
# 116          70.34
# 65           70.06
# 146          82.75
# 115          74.44
# 95           76.48
# 37           78.21
# 4            84.19
# 97           68.57
# 178          84.24
# 70           71.80
# 104          77.55
# 99           82.30
# 100          75.18
# 39           83.23
# 42           71.10
# 3            71.82
# 193          79.64
# 106          72.10
# 9            77.82
# 29           80.17
# 7            85.46
# 10           75.37
# 192          84.03
# 194          74.24
# 47           70.11
# 19           80.58
# 157          75.52
# 1            76.74
# 61           79.41
# 152          81.70

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
m=reg.coef_
# Out:
# array([[3.85145254]])

# %%
c=reg.intercept_
# Out:
# array([51.026937])

# %%
m*40+c
# Out:
# array([[205.08503851]])

# %%
reg.predict([[40]])
# Out:
# c:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[205.08503851]])

# %%
y_pred= reg.predict(X_test)
y_pred
# Out:
# array([[71.28557734],
#        [81.02975227],
#        [76.44652375],
#        [78.02561929],
#        [85.45892268],
#        [74.82891368],
#        [77.87156118],
#        [76.44652375],
#        [77.52493046],
#        [71.3626064 ],
#        [71.8247807 ],
#        [72.01735333],
#        [81.80004277],
#        [73.32684719],
#        [74.48228295],
#        [78.71888074],
#        [84.4190305 ],
#        [71.05449019],
#        [83.45616736],
#        [71.70923712],
#        [78.87293884],
#        [82.10815898],
#        [75.06000083],
#        [81.37638299],
#        [72.05586785],
#        [72.86467289],
#        [80.10540366],
#        [71.59369355],
#        [77.02424163],
#        [79.83580198],
#        [85.65149531],
#        [76.40800922],
#        [84.5730886 ],
#        [75.48366061],
#        [70.32271421],
#        [80.56757796],
#        [74.82891368],
#        [76.29246564],
#        [78.98848242],
#        [82.1466735 ]])

# %%
pd.DataFrame(np.c_[X_test, y_test, y_pred], columns = ["study_hours", "student_marks_original","student_marks_predicted"])
# Out:
#     study_hours  student_marks_original  student_marks_predicted
# 0          5.26                   71.86                71.285577
# 1          7.79                   79.17                81.029752
# 2          6.60                   75.55                76.446524
# 3          7.01                   77.46                78.025619
# 4          8.94                   86.75                85.458923
# 5          6.18                   72.96                74.828914
# 6          6.97                   77.19                77.871561
# 7          6.60                   78.05                76.446524
# 8          6.88                   77.29                77.524930
# 9          5.28                   70.27                71.362606
# 10         5.40                   70.34                71.824781
# 11         5.45                   70.06                72.017353
# 12         7.99                   82.75                81.800043
# 13         5.79                   74.44                73.326847
# 14         6.09                   76.48                74.482283
# 15         7.19                   78.21                78.718881
# 16         8.67                   84.19                84.419030
# 17         5.20                   68.57                71.054490
# 18         8.42                   84.24                83.456167
# 19         5.37                   71.80                71.709237
# 20         7.23                   77.55                78.872939
# 21         8.07                   82.30                82.108159
# 22         6.24                   75.18                75.060001
# 23         7.88                   83.23                81.376383
# 24         5.46                   71.10                72.055868
# 25         5.67                   71.82                72.864673
# 26         7.55                   79.64                80.105404
# 27         5.34                   72.10                71.593694
# 28         6.75                   77.82                77.024242
# 29         7.48                   80.17                79.835802
# 30         8.99                   85.46                85.651495
# 31         6.59                   75.37                76.408009
# 32         8.71                   84.03                84.573089
# 33         6.35                   74.24                75.483661
# 34         5.01                   70.11                70.322714
# 35         7.67                   80.58                80.567578
# 36         6.18                   75.52                74.828914
# 37         6.56                   76.74                76.292466
# 38         7.26                   79.41                78.988482
# 39         8.08                   81.70                82.146674

# %%
reg.score(X_test,y_test)
# Out:
# 0.9499983965528529

# %%
plt.scatter(X_train,y_train)
plt.scatter(X_train,reg.predict(X_train),color='black')
plt.plot(X_train,reg.predict(X_train), 'r-')
plt.plot(X_test, reg.predict(X_test), color = 'yellow')

# %%
y_test
# Out:
#      student_marks
# 131          71.86
# 162          79.17
# 119          75.55
# 46           77.46
# 197          86.75
# 45           72.96
# 180          77.19
# 198          78.05
# 84           77.29
# 40           70.27
# 116          70.34
# 65           70.06
# 146          82.75
# 115          74.44
# 95           76.48
# 37           78.21
# 4            84.19
# 97           68.57
# 178          84.24
# 70           71.80
# 104          77.55
# 99           82.30
# 100          75.18
# 39           83.23
# 42           71.10
# 3            71.82
# 193          79.64
# 106          72.10
# 9            77.82
# 29           80.17
# 7            85.46
# 10           75.37
# 192          84.03
# 194          74.24
# 47           70.11
# 19           80.58
# 157          75.52
# 1            76.74
# 61           79.41
# 152          81.70

# %%
y_pred
# Out:
# array([[71.28557734],
#        [81.02975227],
#        [76.44652375],
#        [78.02561929],
#        [85.45892268],
#        [74.82891368],
#        [77.87156118],
#        [76.44652375],
#        [77.52493046],
#        [71.3626064 ],
#        [71.8247807 ],
#        [72.01735333],
#        [81.80004277],
#        [73.32684719],
#        [74.48228295],
#        [78.71888074],
#        [84.4190305 ],
#        [71.05449019],
#        [83.45616736],
#        [71.70923712],
#        [78.87293884],
#        [82.10815898],
#        [75.06000083],
#        [81.37638299],
#        [72.05586785],
#        [72.86467289],
#        [80.10540366],
#        [71.59369355],
#        [77.02424163],
#        [79.83580198],
#        [85.65149531],
#        [76.40800922],
#        [84.5730886 ],
#        [75.48366061],
#        [70.32271421],
#        [80.56757796],
#        [74.82891368],
#        [76.29246564],
#        [78.98848242],
#        [82.1466735 ]])

# %%
df['absolute_loss'] = y_test-y_pred
df.head()
# Out:
#    study_hours  student_marks  predicted_y  absolute_loss
# 0     6.830000          78.50    77.287139            NaN
# 1     6.560000          76.74    76.235097       0.447534
# 2     6.995949          78.68    77.933750            NaN
# 3     5.670000          71.82    72.767254      -1.044673
# 4     8.670000          84.19    84.456611      -0.229030

# %%
mse = mean_squared_error(y,df['predicted_y'])
mse
# Out:
# 1.0176711552184095

# %%
mae= mean_absolute_error(y,df['predicted_y'])
mae
# Out:
# 0.8075744171102636

# %%
sum(df['absolute_loss'])/len(x)
# Out:
# 0.807574417110263

# %%
reg.score(x,y)
# Out:
# 0.957845054589008
